# %%
import pyttsx3

engine = pyttsx3.init()

for voice in engine.getProperty('voices'):
    print(voice)
# Out:
# <Voice id=com.apple.speech.synthesis.voice.Albert
#           name=Albert
#           languages=['en_US']
#           gender=VoiceGenderNeuter
#           age=None>
# <Voice id=com.apple.voice.compact.it-IT.Alice
#           name=Alice
#           languages=['it_IT']
#           gender=VoiceGenderFemale
#           age=None>
# <Voice id=com.apple.voice.compact.sv-SE.Alva
#           name=Alva
#           languages=['sv_SE']
#           gender=VoiceGenderFemale
#           age=None>
# <Voice id=com.apple.voice.compact.fr-CA.Amelie
#           name=Amélie
#           languages=['fr_CA']
#           gender=VoiceGenderFemale
#           age=None>
# <Voice id=com.apple.voice.compact.ms-MY.Amira
#           name=Amira
#           languages=['ms_MY']
#           gender=VoiceGenderFemale
#           age=None>
# <Voice id=com.apple.voice.compact.de-DE.Anna
#           name=Anna
#           languages=['de_DE']
#           gender=VoiceGenderFemale
#           age=None>
# ...
